# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import requests

url = "https://api.massive.com/v2/reference/news?ticker=AAPL&published_utc=2026-02-11&order=asc&limit=10&sort=published_utc&apiKey=3LurkcZycmdHfWOFx4eQG4ZF_sReGawo"
last_news = requests.get(url).json()
last_news
# Out:
# {'results': [{'id': '9ebf599a659f7d4ced7d2e253042c111b7f372fb9c413d3402acda724b1061f8',
#    'publisher': {'name': 'The Motley Fool',
#     'homepage_url': 'https://www.fool.com/',
#     'logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#     'favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico'},
#    'title': "How High Can Micron Go In the Memory Supercycle? Here's What History Says",
#    'author': 'Jeremy Bowman',
#    'published_utc': '2026-02-11T03:30:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/02/10/how-high-can-micron-go-in-the-memory-supercycle-he/?source=iedfolrf0000001',
#    'tickers': ['MU', 'AMZN', 'MSFT', 'GOOG', 'GOOGL', 'META', 'AAPL'],
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F855507%2Fram-dram-semiconductor-chip-manufacturing-1201x800-5b2df79.jpg&w=1200&op=resize',
# ...

# %%
last_news = pd.DataFrame(last_news['results'])
last_news.head()
# Out:
#                                                   id  \
# 0  9ebf599a659f7d4ced7d2e253042c111b7f372fb9c413d...
# 1  08d0bd28b46b0c0bc43ddfbadd5a1598c3b961e732251c...
# 2  382d764db7741e4cde52aa070b22102239adf9d4badf24...
# 3  4179bba394b279d7aa4746357384798dec56ef07429862...
# 4  319d15d80195746692e2832bd29de6dfc160dc718400e5...
#
#                                            publisher  \
# 0  {'name': 'The Motley Fool', 'homepage_url': 'h...
# 1  {'name': 'The Motley Fool', 'homepage_url': 'h...
# 2  {'name': 'The Motley Fool', 'homepage_url': 'h...
# 3  {'name': 'Benzinga', 'homepage_url': 'https://...
# 4  {'name': 'Investing.com', 'homepage_url': 'htt...
#
#                                                title  \
# 0  How High Can Micron Go In the Memory Supercycl...
# 1  Which Big Tech Stocks Have the Most Debt, and ...
# 2  Taiwan Semiconductor Manufacturing (TSM) CEO C...
# 3  Apple Stock To Rise Despite Memory Chip Crunch...
# ...

# %%
last_news["date"] = pd.to_datetime(last_news["published_utc"])
last_news.head()
# Out:
#                                                   id  \
# 0  9ebf599a659f7d4ced7d2e253042c111b7f372fb9c413d...
# 1  08d0bd28b46b0c0bc43ddfbadd5a1598c3b961e732251c...
# 2  382d764db7741e4cde52aa070b22102239adf9d4badf24...
# 3  4179bba394b279d7aa4746357384798dec56ef07429862...
# 4  319d15d80195746692e2832bd29de6dfc160dc718400e5...
#
#                                            publisher  \
# 0  {'name': 'The Motley Fool', 'homepage_url': 'h...
# 1  {'name': 'The Motley Fool', 'homepage_url': 'h...
# 2  {'name': 'The Motley Fool', 'homepage_url': 'h...
# 3  {'name': 'Benzinga', 'homepage_url': 'https://...
# 4  {'name': 'Investing.com', 'homepage_url': 'htt...
#
#                                                title  \
# 0  How High Can Micron Go In the Memory Supercycl...
# 1  Which Big Tech Stocks Have the Most Debt, and ...
# 2  Taiwan Semiconductor Manufacturing (TSM) CEO C...
# 3  Apple Stock To Rise Despite Memory Chip Crunch...
# ...
